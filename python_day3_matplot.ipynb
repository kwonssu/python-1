# %% [markdown]
# # 4장 기본 그래프 그리기

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(np.arange(4)*10) # Y
#plt.show() # print 안해도 출력되듯이 show() 하지 않아도 그려집니다.

# %%
# 안써도 됨. 그림을 이 문서 안에 그려라
# %matplotlib inline

# %%
plt.plot([1,2,3,4],[12,43,25,15]) # (X, Y)

# %%
plt.title('plotting')
plt.plot([1,2,3,4],[12,43,25,50], 'r.',label='A', color='blue' )
plt.plot([1,2,3,4],[20,44,55,10], 'g^', label='B', color='red', linestyle=':')
plt.plot([1,2,3,4],[1,5,10,30], label='C', color='violet',linestyle='--')
plt.legend(loc=10)
# 순서 무관

# %%
import pandas
df0=pandas.read_csv('2018.csv')
arr0=np.array(df0)
df1=pandas.read_csv('2019.csv')
arr1=np.array(df1)
arr=np.concatenate((arr0,arr1),axis=0)

# %%
plt.figure(figsize=(40,10))
plt.plot(arr[:,0], arr[:,1], label='open')
plt.plot(arr[:,2], label='high')
plt.plot(arr[:,3], label='low')
plt.plot(arr[:,4], label='close')
plt.legend()
plt.title('Dow stock')
# Out:
# Text(0.5, 1.0, 'Dow stock')

# %%
arr[:,0]
# Out:
# array(['2017-06-19', '2017-06-20', '2017-06-21', '2017-06-22',
#        '2017-06-23', '2017-06-26', '2017-06-27', '2017-06-28',
#        '2017-06-29', '2017-06-30', '2017-07-03', '2017-07-05',
#        '2017-07-06', '2017-07-07', '2017-07-10', '2017-07-11',
#        '2017-07-12', '2017-07-13', '2017-07-14', '2017-07-17',
#        '2017-07-18', '2017-07-19', '2017-07-20', '2017-07-21',
#        '2017-07-24', '2017-07-25', '2017-07-26', '2017-07-27',
#        '2017-07-28', '2017-07-31', '2017-08-01', '2017-08-02',
#        '2017-08-03', '2017-08-04', '2017-08-07', '2017-08-08',
#        '2017-08-09', '2017-08-10', '2017-08-11', '2017-08-14',
#        '2017-08-15', '2017-08-16', '2017-08-17', '2017-08-18',
#        '2017-08-21', '2017-08-22', '2017-08-23', '2017-08-24',
#        '2017-08-25', '2017-08-28', '2017-08-29', '2017-08-30',
#        '2017-08-31', '2017-09-01', '2017-09-05', '2017-09-06',
#        '2017-09-07', '2017-09-08', '2017-09-11', '2017-09-12',
# ...
