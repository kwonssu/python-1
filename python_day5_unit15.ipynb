# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table', header=0, index_col=0)
print(df)
# Out:
# [Empty DataFrame
# Columns: []
# Index: [Main topics, Bids Boycotts Ceremonies Charter Host cities IFs IOC Medal Medal tables Medalists NOCs Pierre de Coubertin medal Scandals and controversies Sports Symbols Torch relays Venues Women participation, Games, Summer Winter Summer Paralympic Winter Paralympic Youth Deaflympics Special African American Asian European Pacific Ancient Intercalated, vte],                                              Summer Games  Summer Games.1  \
# Team (IOC code)                                         №             NaN
# Afghanistan (AFG)                                      14             0.0
# Algeria (ALG)                                          13             5.0
# Argentina (ARG)                                        24            21.0
# Armenia (ARM)                                           6             2.0
# Australasia (ANZ) [ANZ]                                 2             3.0
# ...

# %%
df[1]
# Out:
#                                              Summer Games  Summer Games.1  \
# Team (IOC code)                                         №             NaN
# Afghanistan (AFG)                                      14             0.0
# Algeria (ALG)                                          13             5.0
# Argentina (ARG)                                        24            21.0
# Armenia (ARM)                                           6             2.0
# Australasia (ANZ) [ANZ]                                 2             3.0
# Australia (AUS) [AUS] [Z]                              26           147.0
# Austria (AUT)                                          27            18.0
# Azerbaijan (AZE)                                        6             7.0
# Bahamas (BAH)                                          16             6.0
# Bahrain (BRN)                                           9             2.0
# Barbados (BAR) [BAR]                                   12             0.0
# ...

# %%
len(df) #리스트 안에 요소 16개
# Out:
# 16

# %%
df[2].head()
# Out:
#                            № Summer  № Winter  № Games
# Team (IOC code)
# Albania (ALB)                     8         4       12
# American Samoa (ASA)              8         1        9
# Andorra (AND)                    11        12       23
# Angola (ANG)                      9         0        9
# Antigua and Barbuda (ANT)        10         0       10

# %%
data = df[1]
data.head()
# Out:
#                   Summer Games  Summer Games.1  Summer Games.2  \
# Team (IOC code)              №             NaN             NaN
# Afghanistan (AFG)           14             0.0             0.0
# Algeria (ALG)               13             5.0             4.0
# Argentina (ARG)             24            21.0            25.0
# Armenia (ARM)                6             2.0             6.0
#
#                    Summer Games.3 Summer Games.4 Winter Games  Winter Games.1  \
# Team (IOC code)               NaN          Total            №             NaN
# Afghanistan (AFG)             2.0              2            0             0.0
# Algeria (ALG)                 8.0             17            3             0.0
# Argentina (ARG)              28.0             74           19             0.0
# Armenia (ARM)                 6.0             14            7             0.0
#
#                    Winter Games.2  Winter Games.3 Winter Games.4  \
# ...

# %%
type(data) # 타입 : 데이터 프레임
# Out:
# pandas.core.frame.DataFrame

# %%
data.columns, data.index, data.values
# Out:
# (Index(['Summer Games', 'Summer Games.1', 'Summer Games.2', 'Summer Games.3',
#         'Summer Games.4', 'Winter Games', 'Winter Games.1', 'Winter Games.2',
#         'Winter Games.3', 'Winter Games.4', 'Combined Total',
#         'Combined Total.1', 'Combined Total.2', 'Combined Total.3',
#         'Combined Total.4'],
#        dtype='object'),
#  Index(['Team (IOC code)', 'Afghanistan (AFG)', 'Algeria (ALG)',
#         'Argentina (ARG)', 'Armenia (ARM)', 'Australasia (ANZ) [ANZ]',
#         'Australia (AUS) [AUS] [Z]', 'Austria (AUT)', 'Azerbaijan (AZE)',
#         'Bahamas (BAH)',
#         ...
#         'Virgin Islands (ISV)', 'Yugoslavia (YUG) [YUG]', 'Zambia (ZAM) [ZAM]',
#         'Zimbabwe (ZIM) [ZIM]', 'Unified Team (EUN) [EUN]',
#         'Independent Olympic Athletes (IOA) [IOA]',
#         'Independent Olympic Participants (IOP) [IOP]',
#         'Olympic Athletes from Russia (OAR) [OAR]', 'Mixed team (ZZX) [ZZX]',
#         'Totals'],
# ...

# %%
data.shape
# Out:
# (154, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 154 entries, Team (IOC code) to Totals
# Data columns (total 15 columns):
# Summer Games        154 non-null object
# Summer Games.1      153 non-null float64
# Summer Games.2      153 non-null float64
# Summer Games.3      153 non-null float64
# Summer Games.4      154 non-null object
# Winter Games        154 non-null object
# Winter Games.1      153 non-null float64
# Winter Games.2      153 non-null float64
# Winter Games.3      153 non-null float64
# Winter Games.4      154 non-null object
# Combined Total      154 non-null object
# Combined Total.1    153 non-null float64
# Combined Total.2    153 non-null float64
# Combined Total.3    153 non-null float64
# Combined Total.4    154 non-null object
# dtypes: float64(9), object(6)
# memory usage: 19.2+ KB

# %%
data.describe() # 기술하다, 통계치 구하기
# Out:
#        Summer Games.1  Summer Games.2  Summer Games.3  Winter Games.1  \
# count      153.000000      153.000000      153.000000      153.000000
# mean        66.862745       66.418301       71.725490       13.882353
# std        422.599849      416.404023      447.853436       87.722270
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000        1.000000        1.000000        0.000000
# 50%          3.000000        4.000000        6.000000        0.000000
# 75%         26.000000       30.000000       31.000000        1.000000
# max       5115.000000     5081.000000     5487.000000     1062.000000
#
#        Winter Games.2  Winter Games.3  Combined Total.1  Combined Total.2  \
# count      153.000000      153.000000        153.000000        153.000000
# mean        13.830065       13.725490         80.745098         80.248366
# std         87.279179       86.350893        508.851901        502.521776
# ...

# %%
data.head(3), data.tail(3)
# Out:
# (                  Summer Games  Summer Games.1  Summer Games.2  \
#  Team (IOC code)              №             NaN             NaN
#  Afghanistan (AFG)           14             0.0             0.0
#  Algeria (ALG)               13             5.0             4.0
#
#                     Summer Games.3 Summer Games.4 Winter Games  Winter Games.1  \
#  Team (IOC code)               NaN          Total            №             NaN
#  Afghanistan (AFG)             2.0              2            0             0.0
#  Algeria (ALG)                 8.0             17            3             0.0
#
#                     Winter Games.2  Winter Games.3 Winter Games.4  \
#  Team (IOC code)               NaN             NaN          Total
#  Afghanistan (AFG)             0.0             0.0              0
#  Algeria (ALG)                 0.0             0.0              0
#
#                    Combined Total  Combined Total.1  Combined Total.2  \
# ...

# %%
data.sample(5) # 아무거나 x건
# Out:
#                     Summer Games  Summer Games.1  Summer Games.2  \
# Saudi Arabia (KSA)            11             0.0             1.0
# Romania (ROU)                 21            89.0            95.0
# Samoa (SAM)                    9             0.0             1.0
# Cyprus (CYP)                  10             0.0             1.0
# Jamaica (JAM) [JAM]           17            22.0            35.0
#
#                      Summer Games.3 Summer Games.4 Winter Games  \
# Saudi Arabia (KSA)              2.0              3            0
# Romania (ROU)                 122.0            306           21
# Samoa (SAM)                     0.0              1            0
# Cyprus (CYP)                    0.0              1           11
# Jamaica (JAM) [JAM]            21.0             78            8
#
#                      Winter Games.1  Winter Games.2  Winter Games.3  \
# Saudi Arabia (KSA)              0.0             0.0             0.0
# ...

# %%
d = {'a':1, 'b':[1,2,3], 'c':100}
d['a'], d['b']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-c0f4dfe0bc60> in <module>
#       1 d = {'a':1, 'b':[1,2,3], 'c':100}
# ----> 2 d['a'], d['b'], d.a
#
# AttributeError: 'dict' object has no attribute 'a'

# %%
data[['Summer Games.1', 'Summer Games.2']].head() #몇개의 컬럼만 뽑기
# Out:
#                    Summer Games.1  Summer Games.2
# Team (IOC code)               NaN             NaN
# Afghanistan (AFG)             0.0             0.0
# Algeria (ALG)                 5.0             4.0
# Argentina (ARG)              21.0            25.0
# Armenia (ARM)                 2.0             6.0

# %%
# 데이터 프레임은 딕셔너리 구조로 되어있스빈다.
data['Summer Games.1'].head()
# Out:
# Team (IOC code)       NaN
# Afghanistan (AFG)     0.0
# Algeria (ALG)         5.0
# Argentina (ARG)      21.0
# Armenia (ARM)         2.0
# Name: Summer Games.1, dtype: float64

# %%
#data[0] 에 해당, i(index)loc(ation)
data.iloc[:5] # == data.head()
data.iloc[:5, :3]
# Out:
#                   Summer Games  Summer Games.1  Summer Games.2
# Team (IOC code)              №             NaN             NaN
# Afghanistan (AFG)           14             0.0             0.0
# Algeria (ALG)               13             5.0             4.0
# Argentina (ARG)             24            21.0            25.0
# Armenia (ARM)                6             2.0             6.0

# %%
data.dtypes # data.info()로 타입검사
#수치형이어야 하는데 object로 잡혔다면 누락이나 오타가 있는것 > 조치필요
# Out:
# Summer Games         object
# Summer Games.1      float64
# Summer Games.2      float64
# Summer Games.3      float64
# Summer Games.4       object
# Winter Games         object
# Winter Games.1      float64
# Winter Games.2      float64
# Winter Games.3      float64
# Winter Games.4       object
# Combined Total       object
# Combined Total.1    float64
# Combined Total.2    float64
# Combined Total.3    float64
# Combined Total.4     object
# dtype: object

# %%
data.dropna().max() # 컬럼별최대값
# Out:
# Summer Games           9.0
# Summer Games.1      5115.0
# Summer Games.2      5081.0
# Summer Games.3      5487.0
# Summer Games.4        91.0
# Winter Games           9.0
# Winter Games.1      1062.0
# Winter Games.2      1058.0
# Winter Games.3      1050.0
# Winter Games.4         9.0
# Combined Total         9.0
# Combined Total.1    6177.0
# Combined Total.2    6139.0
# Combined Total.3    6537.0
# Combined Total.4      96.0
# dtype: float64

# %%
new_data = data.dropna()
new_data.head()
# Out:
#                         Summer Games  Summer Games.1  Summer Games.2  \
# Afghanistan (AFG)                 14             0.0             0.0
# Algeria (ALG)                     13             5.0             4.0
# Argentina (ARG)                   24            21.0            25.0
# Armenia (ARM)                      6             2.0             6.0
# Australasia (ANZ) [ANZ]            2             3.0             4.0
#
#                          Summer Games.3 Summer Games.4 Winter Games  \
# Afghanistan (AFG)                   2.0              2            0
# Algeria (ALG)                       8.0             17            3
# Argentina (ARG)                    28.0             74           19
# Armenia (ARM)                       6.0             14            7
# Australasia (ANZ) [ANZ]             5.0             12            0
#
#                          Winter Games.1  Winter Games.2  Winter Games.3  \
# ...

# %%
#data[10:20, :2] # 행은 선택이 되는데 컬럼 선택이 안됩니다.
테스트 = data.iloc[10:20, :2]
테스트
# Out:
#                                 Summer Games  Summer Games.1
# Bahrain (BRN)                              9             2.0
# Barbados (BAR) [BAR]                      12             0.0
# Belarus (BLR)                              6            12.0
# Belgium (BEL)                             26            40.0
# Bermuda (BER)                             18             0.0
# Bohemia (BOH) [BOH] [Z]                    3             0.0
# Botswana (BOT)                            10             0.0
# Brazil (BRA)                              22            30.0
# British West Indies (BWI) [BWI]            1             0.0
# Bulgaria (BUL) [H]                        20            51.0

# %%
테스트.columns=['경기수','금']
테스트
# Out:
#                                 경기수     금
# Bahrain (BRN)                     9   2.0
# Barbados (BAR) [BAR]             12   0.0
# Belarus (BLR)                     6  12.0
# Belgium (BEL)                    26  40.0
# Bermuda (BER)                    18   0.0
# Bohemia (BOH) [BOH] [Z]           3   0.0
# Botswana (BOT)                   10   0.0
# Brazil (BRA)                     22  30.0
# British West Indies (BWI) [BWI]   1   0.0
# Bulgaria (BUL) [H]               20  51.0

# %%
테스트.경기수
# Out:
# Bahrain (BRN)                       9
# Barbados (BAR) [BAR]               12
# Belarus (BLR)                       6
# Belgium (BEL)                      26
# Bermuda (BER)                      18
# Bohemia (BOH) [BOH] [Z]             3
# Botswana (BOT)                     10
# Brazil (BRA)                       22
# British West Indies (BWI) [BWI]     1
# Bulgaria (BUL) [H]                 20
# Name: 경기수, dtype: object

# %%
new_data.sort_values('Summer Games', ascending=False).head()
# Out:
#                            Summer Games  Summer Games.1  Summer Games.2  \
# Lithuania (LTU)                       9             6.0             6.0
# Mauritius (MRI)                       9             0.0             0.0
# United Arab Emirates (UAE)            9             1.0             0.0
# Qatar (QAT)                           9             0.0             1.0
# Samoa (SAM)                           9             0.0             1.0
#
#                             Summer Games.3 Summer Games.4 Winter Games  \
# Lithuania (LTU)                       13.0             25            9
# Mauritius (MRI)                        1.0              1            0
# United Arab Emirates (UAE)             1.0              2            0
# Qatar (QAT)                            4.0              5            0
# Samoa (SAM)                            0.0              1            0
#
#                             Winter Games.1  Winter Games.2  Winter Games.3  \
# ...

# %%
#256~ 데이터를 엑셀로 저장하기
summer = data.iloc[1:,:5]
summer.head()
# Out:
#                         Summer Games  Summer Games.1  Summer Games.2  \
# Afghanistan (AFG)                 14             0.0             0.0
# Algeria (ALG)                     13             5.0             4.0
# Argentina (ARG)                   24            21.0            25.0
# Armenia (ARM)                      6             2.0             6.0
# Australasia (ANZ) [ANZ]            2             3.0             4.0
#
#                          Summer Games.3 Summer Games.4
# Afghanistan (AFG)                   2.0              2
# Algeria (ALG)                       8.0             17
# Argentina (ARG)                    28.0             74
# Armenia (ARM)                       6.0             14
# Australasia (ANZ) [ANZ]             5.0             12

# %%
summer.columns = ['경기수','금','은','동','계']
summer_sort=summer.sort_values('금',ascending=False)

# %%
summer_sort.head()
# Out:
#                                     경기수       금       은       동      계
# Totals                               28  5115.0  5081.0  5487.0  15683
# United States (USA) [P] [Q] [R] [Z]  27  1022.0   795.0   705.0   2522
# Soviet Union (URS) [URS]              9   395.0   319.0   296.0   1010
# Great Britain (GBR) [GBR] [Z]        28   263.0   295.0   293.0    851
# China (CHN) [CHN]                    10   224.0   167.0   155.0    546

# %%
summer_sort.to_excel('올림픽하계금메달.xlsx')

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_table_of_the_FIFA_World_Cup', header=2, index_col=0)
print(df)
# Out:
# [                       Team   T    S    P   W   D   L    F    A    GD  T.1  \
# №
# 1                    Brazil  21  +21  109  73  18  18  229  105  +124  237
# 2                Germany[A]  19  +17  109  67  20  22  226  125  +101  221
# 3                     Italy  18   −1   83  45  21  17  128   77   +51  156
# 4                 Argentina  17  +12   81  43  15  23  137   93   +44  144
# 5                    France  15   +6   66  34  13  19  120   77   +43  115
# 6                   England  15   +6   69  29  21  19   91   64   +27  108
# 7                     Spain  15  +11   63  30  15  18   99   72   +27  105
# 8               Netherlands  10   −1   50  27  12  11   86   48   +38   93
# 9                   Uruguay  13   +3   56  24  12  20   87   74   +13   84
# 10                   Sweden  12   +1   51  19  13  19   80   73    +7   70
# 11                  Belgium  13   +2   48  20   9  19   68   72    −4   69
# ...

# %%
df[0].head()
# Out:
#          Team   T    S    P   W   D   L    F    A    GD  T.1    A.1  T.2  \
# №
# 1      Brazil  21  +21  109  73  18  18  229  105  +124  237  2.174  164
# 2  Germany[A]  19  +17  109  67  20  22  226  125  +101  221  2.028  154
# 3       Italy  18   −1   83  45  21  17  128   77   +51  156  1.880  111
# 4   Argentina  17  +12   81  43  15  23  137   93   +44  144  1.778  101
# 5      France  15   +6   66  34  13  19  120   77   +43  115  1.742   81
#
#      A.2  T.3    A.3                              Best finish Confederation
# №
# 1  1.505  193  1.771  Champion (1958, 1962, 1970, 1994, 2002)      CONMEBOL
# 2  1.413  182  1.670        Champion (1954, 1974, 1990, 2014)          UEFA
# 3  1.337  125  1.506        Champion (1934, 1938, 1982, 2006)          UEFA
# 4  1.247  120  1.481                    Champion (1978, 1986)      CONMEBOL
# 5  1.227  100  1.515                    Champion (1998, 2018)          UEFA

# %%
worldcup = df[0]

# %%
len(df)
# Out:
# 4

# %%
for i in range(len(df)):
    data = df[i]
    print(data.shape)
# Out:
# (79, 18)
# (12, 18)
# (11, 1)
# (6, 1)

# %%
worldcup.head()
# Out:
#          Team   T    S    P   W   D   L    F    A    GD  T.1    A.1  T.2  \
# №
# 1      Brazil  21  +21  109  73  18  18  229  105  +124  237  2.174  164
# 2  Germany[A]  19  +17  109  67  20  22  226  125  +101  221  2.028  154
# 3       Italy  18   −1   83  45  21  17  128   77   +51  156  1.880  111
# 4   Argentina  17  +12   81  43  15  23  137   93   +44  144  1.778  101
# 5      France  15   +6   66  34  13  19  120   77   +43  115  1.742   81
#
#      A.2  T.3    A.3                              Best finish Confederation
# №
# 1  1.505  193  1.771  Champion (1958, 1962, 1970, 1994, 2002)      CONMEBOL
# 2  1.413  182  1.670        Champion (1954, 1974, 1990, 2014)          UEFA
# 3  1.337  125  1.506        Champion (1934, 1938, 1982, 2006)          UEFA
# 4  1.247  120  1.481                    Champion (1978, 1986)      CONMEBOL
# 5  1.227  100  1.515                    Champion (1998, 2018)          UEFA

# %%
worldcup.columns, worldcup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79 entries, 1 to 79
# Data columns (total 18 columns):
# Team             79 non-null object
# T                79 non-null int64
# S                79 non-null object
# P                79 non-null int64
# W                79 non-null int64
# D                79 non-null int64
# L                79 non-null int64
# F                79 non-null int64
# A                79 non-null int64
# GD               79 non-null object
# T.1              79 non-null int64
# A.1              79 non-null float64
# T.2              79 non-null int64
# A.2              79 non-null float64
# T.3              79 non-null int64
# A.3              79 non-null float64
# Best finish      79 non-null object
# Confederation    79 non-null object
# dtypes: float64(3), int64(10), object(5)
# memory usage: 11.7+ KB
# (Index(['Team', 'T', 'S', 'P', 'W', 'D', 'L', 'F', 'A', 'GD', 'T.1', 'A.1',
#         'T.2', 'A.2', 'T.3', 'A.3', 'Best finish', 'Confederation'],
# ...

# %%
# 컬럼 'T' 내림차순으로 정렬해서 엑셀로 저장합니다.
worldcup_sort = worldcup.sort_values('T', ascending=False)
worldcup_sort.to_excel('worldcup.xlsx')

# %%
'South Korea' in worldcup.Team.values
# Out:
# True

# %%
url='https://finance.naver.com'
df = pd.read_html(url, encoding='cp949', header=0, index_col=0)

# %%
len(df)
# Out:
# 12

# %%
wise = df[0]

# %%
wise_save = wise.iloc[1:,1::2] #1번째 컬럼부터 2칸씩 떨어져서
wise_save
# Out:
#               1주       누적       추천일
# 종목명
# 아이앤씨     +17.80%  +14.02%  19.06.14
# 이녹스첨단소재  +16.34%  +31.22%  19.05.23
# 파수닷컴     +12.41%  +21.10%  19.05.21
# 인선이엔티    +11.08%  -13.37%  19.05.02
# 디바이스이엔지  +10.48%    0.00%  19.03.20

# %%
wise_save = wise_save.replace('%', '',regex=True)

# %%
wise_save.to_excel('naver_wise.xlsx')

# %%
for i in range(len(df)):
        data= df[i]
        print(data.shape)
# Out:
# (6, 6)
# (4, 3)
# (4, 3)
# (4, 3)
# (4, 2)
# (4, 2)
# (4, 2)
# (4, 2)
# (2, 2)
# (4, 2)
# (5, 2)
# (5, 2)

# %%
c1 = wise_save['1주']
c1
# Out:
# 종목명
# 아이앤씨       +17.80
# 이녹스첨단소재    +16.34
# 파수닷컴       +12.41
# 인선이엔티      +11.08
# 디바이스이엔지    +10.48
# Name: 1주, dtype: object

# %% [markdown]
# - 259 pandas란 panel datas 데이터 분석용 라이브러리
# - values 를 numpy로 관리
# - 컬럼 > 시리즈, 표 > 데이터 프레임

# %%
index = pd.date_range('1/1/2000', periods=8)

# %%
index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
# dataframe의 구성요서 (values, index, columns)
#df = pd.DataFrame(np.random.rand(8,3), index=index, columns=list('abc'))
df = pd.DataFrame(np.random.rand(8,3), index=index, columns=['A','B','C'])

# %%
df
# Out:
#                    A         B         C
# 2000-01-01  0.431617  0.455972  0.836514
# 2000-01-02  0.333824  0.334924  0.449513
# 2000-01-03  0.469613  0.413067  0.715256
# 2000-01-04  0.985628  0.625132  0.802915
# 2000-01-05  0.111760  0.073373  0.221998
# 2000-01-06  0.112153  0.572376  0.291370
# 2000-01-07  0.619019  0.478613  0.869992
# 2000-01-08  0.590248  0.743318  0.956277

# %%
# a컬럼에서 0.5보다 큰 값만 뽑기
a = df['A']
a[a>0.5]
# Out:
# 2000-01-04    0.985628
# 2000-01-07    0.619019
# 2000-01-08    0.590248
# Name: A, dtype: float64

# %%
df.T
# Out:
#    2000-01-01  2000-01-02  2000-01-03  2000-01-04  2000-01-05  2000-01-06  \
# A    0.431617    0.333824    0.469613    0.985628    0.111760    0.112153
# B    0.455972    0.334924    0.413067    0.625132    0.073373    0.572376
# C    0.836514    0.449513    0.715256    0.802915    0.221998    0.291370
#
#    2000-01-07  2000-01-08
# A    0.619019    0.590248
# B    0.478613    0.743318
# C    0.869992    0.956277

# %%
df['D'] = df['A']+df['B']/2

# %%
df
# Out:
#                    A         B         C         D
# 2000-01-01  0.431617  0.455972  0.836514  0.659603
# 2000-01-02  0.333824  0.334924  0.449513  0.501286
# 2000-01-03  0.469613  0.413067  0.715256  0.676146
# 2000-01-04  0.985628  0.625132  0.802915  1.298194
# 2000-01-05  0.111760  0.073373  0.221998  0.148446
# 2000-01-06  0.112153  0.572376  0.291370  0.398341
# 2000-01-07  0.619019  0.478613  0.869992  0.858325
# 2000-01-08  0.590248  0.743318  0.956277  0.961907

# %%
#dictionary에 새로운 키 추가하기
d={'a':4, 'b':5} #'c' :10
d['c']=10
d
# Out:
# {'a': 4, 'b': 5, 'c': 10}

# %%
del d['a']
d
# Out:
# {'b': 5, 'c': 10}

# %%
#del df['a']

# %%
del df['E']
df['E']=np.sum(df, axis=1)
df.head()
# Out:
#                    A         B         C         D         E
# 2000-01-01  0.431617  0.455972  0.836514  0.659603  2.383706
# 2000-01-02  0.333824  0.334924  0.449513  0.501286  1.619548
# 2000-01-03  0.469613  0.413067  0.715256  0.676146  2.274082
# 2000-01-04  0.985628  0.625132  0.802915  1.298194  3.711869
# 2000-01-05  0.111760  0.073373  0.221998  0.148446  0.555577

# %%
df.iloc[0:2]
# Out:
#                    A         B         C         D          E
# 2000-01-01  0.431617  0.455972  0.836514  0.659603  16.685942
# 2000-01-02  0.333824  0.334924  0.449513  0.501286  11.336833

# %%
df.to_csv('test.csv')

# %% [markdown]
# - #268 pandas로 인구 구조 분석하기

# %%
df = pd.read_csv('age.csv', encoding='cp949', index_col=0)
df = df.replace(',','',regex=True)
df = df.dropna()

# %%
a = df.astype('int')
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3841 entries, 서울특별시  (1100000000) to 제주특별자치도 서귀포시 예래동(5013062000)
# Columns: 103 entries, 2019년02월_계_총인구수 to 2019년02월_계_100세 이상
# dtypes: int32(103)
# memory usage: 1.5+ MB

# %%
b = a.div(a['2019년02월_계_총인구수'], axis=0) # a.div(a.iloc(:,0), axis=0)
del b['2019년02월_계_총인구수'], b['2019년02월_계_연령구간인구수'] # c = b.iloc[:, 2:] # 컬럼 2개 빼고 선택
c = b

# %%
c.head()
# Out:
#                              2019년02월_계_0세  2019년02월_계_1세  2019년02월_계_2세  \
# 행정구역
# 서울특별시  (1100000000)               0.005500       0.006100       0.006736
# 서울특별시 종로구 (1111000000)            0.003879       0.004468       0.005069
# 서울특별시 종로구 청운효자동(1111051500)       0.005073       0.006072       0.005534
# 서울특별시 종로구 사직동(1111053000)         0.004487       0.005217       0.006678
# 서울특별시 종로구 삼청동(1111054000)         0.003191       0.005319       0.001064
#
#                              2019년02월_계_3세  2019년02월_계_4세  2019년02월_계_5세  \
# 행정구역
# 서울특별시  (1100000000)               0.007239       0.007168       0.007062
# 서울특별시 종로구 (1111000000)            0.005717       0.005573       0.005645
# 서울특별시 종로구 청운효자동(1111051500)       0.007533       0.007533       0.007225
# 서울특별시 종로구 사직동(1111053000)         0.006991       0.006991       0.007304
# 서울특별시 종로구 삼청동(1111054000)         0.007447       0.003901       0.004610
#
# ...

# %%
#2. 궁금한 지역의 이름을 입력받는다
name = input('궁금한 지역이 어디에요?')
# Out:
# 궁금한 지역이 어디에요?반곡관설동

# %%
name
# Out:
# '반곡관설동'

# %%
c.index
# Out:
# Index(['서울특별시  (1100000000)', '서울특별시 종로구 (1111000000)',
#        '서울특별시 종로구 청운효자동(1111051500)', '서울특별시 종로구 사직동(1111053000)',
#        '서울특별시 종로구 삼청동(1111054000)', '서울특별시 종로구 부암동(1111055000)',
#        '서울특별시 종로구 평창동(1111056000)', '서울특별시 종로구 무악동(1111057000)',
#        '서울특별시 종로구 교남동(1111058000)', '서울특별시 종로구 가회동(1111060000)',
#        ...
#        '제주특별자치도 서귀포시 중앙동(5013053000)', '제주특별자치도 서귀포시 천지동(5013054000)',
#        '제주특별자치도 서귀포시 효돈동(5013055000)', '제주특별자치도 서귀포시 영천동(5013056000)',
#        '제주특별자치도 서귀포시 동홍동(5013057000)', '제주특별자치도 서귀포시 서홍동(5013058000)',
#        '제주특별자치도 서귀포시 대륜동(5013059000)', '제주특별자치도 서귀포시 대천동(5013060000)',
#        '제주특별자치도 서귀포시 중문동(5013061000)', '제주특별자치도 서귀포시 예래동(5013062000)'],
#       dtype='object', name='행정구역', length=3841)

# %%
mask = c.index.str.contains(name)

# %%
c.index.str.contains(name).sum()
# Out:
# 1

# %%
df2 = c[mask]
df2.head(2)
# Out:
#                            2019년02월_계_0세  2019년02월_계_1세  2019년02월_계_2세  \
# 행정구역
# 강원도 원주시 반곡관설동(4213067500)       0.008635       0.011441       0.012651
#
#                            2019년02월_계_3세  2019년02월_계_4세  2019년02월_계_5세  \
# 행정구역
# 강원도 원주시 반곡관설동(4213067500)       0.013618       0.013497       0.013836
#
#                            2019년02월_계_6세  2019년02월_계_7세  2019년02월_계_8세  \
# 행정구역
# 강원도 원주시 반곡관설동(4213067500)       0.015384       0.014924       0.015094
#
#                            2019년02월_계_9세  ...  2019년02월_계_91세  2019년02월_계_92세  \
# 행정구역                                      ...
# 강원도 원주시 반곡관설동(4213067500)       0.013013  ...         0.00029        0.000363
#
#                            2019년02월_계_93세  2019년02월_계_94세  2019년02월_계_95세  \
# 행정구역
# 강원도 원주시 반곡관설동(4213067500)         0.00029        0.000121        0.000194
#
#                            2019년02월_계_96세  2019년02월_계_97세  2019년02월_계_98세  \
# 행정구역
# ...

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
df2.T.plot()
plt.show()

# %%
df = c
x = df.sub(df2.iloc[0], axis=1)
y = np.power(x,2)
z = y.sum(axis=1)

# %%
i = z.sort_values().index[:10]

# %%
df.loc[i].T.plot()
plt.show()

# %%
url = 'file:///C:/Users/wtime/Downloads/%ED%8C%80%20%ED%83%80%EA%B2%A9%EB%A9%94%EC%9D%B8%EA%B8%B0%EB%A1%9D%20_%20KBReport.html'
tables = pd.read_html(url, index_col=1)
len(tables)
# Out:
# 1

# %%
baseball = tables[0]

# %%
baseball.shape
# Out:
# (11, 20)

# %%
data = baseball.iloc[:-1]

# %%
data.head()
# Out:
#         #  경기   승  무   패     승률   기대승률   R/G   득점  홈런  도루   볼넷%   삼진%  BABIP  \
# 팀명
# SK    1.0  77  51  1  25  0.671  0.606  4.70  362  69  56   8.5  17.7  0.303
# 두산    2.0  78  48  0  30  0.615  0.625  5.03  392  47  52  11.3  15.5  0.313
# LG    3.0  76  43  1  32  0.573  0.522  4.25  323  48  55   8.1  17.0  0.303
# Hero  4.0  79  45  0  34  0.570  0.597  5.34  422  59  57   9.3  17.2  0.326
# NC    5.0  76  37  0  39  0.487  0.486  4.64  353  71  37   7.7  16.9  0.318
#
#          타율    출루율    장타율    OPS   wOBA    WAR
# 팀명
# SK    0.263  0.337  0.387  0.724  0.329   8.69
# 두산    0.273  0.361  0.390  0.751  0.346  14.22
# LG    0.260  0.329  0.368  0.697  0.318   5.22
# Hero  0.280  0.353  0.409  0.762  0.346  14.43
# NC    0.279  0.343  0.419  0.762  0.342  11.71

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, SK to 롯데
# Data columns (total 20 columns):
# #        10 non-null float64
# 경기       10 non-null int64
# 승        10 non-null int64
# 무        10 non-null int64
# 패        10 non-null int64
# 승률       10 non-null object
# 기대승률     10 non-null object
# R/G      10 non-null float64
# 득점       10 non-null int64
# 홈런       10 non-null int64
# 도루       10 non-null int64
# 볼넷%      10 non-null float64
# 삼진%      10 non-null float64
# BABIP    10 non-null float64
# 타율       10 non-null float64
# 출루율      10 non-null float64
# 장타율      10 non-null float64
# OPS      10 non-null float64
# wOBA     10 non-null float64
# WAR      10 non-null float64
# dtypes: float64(11), int64(7), object(2)
# memory usage: 1.6+ KB

# %%
#warning떠서 API로 대체합니다.
#data['승률'] = data['승률'].astype('float') # 타입 변경 후 write
#data['기대승률']=data['기대승률'].astype('float')
data.loc[:,'승률'] = data['승률'].astype('float')
data.loc[:,'기대승률'] = data['기대승률'].astype('float')
# Out:
# C:\Users\wtime\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, SK to 롯데
# Data columns (total 20 columns):
# #        10 non-null float64
# 경기       10 non-null int64
# 승        10 non-null int64
# 무        10 non-null int64
# 패        10 non-null int64
# 승률       10 non-null float64
# 기대승률     10 non-null float64
# R/G      10 non-null float64
# 득점       10 non-null int64
# 홈런       10 non-null int64
# 도루       10 non-null int64
# 볼넷%      10 non-null float64
# 삼진%      10 non-null float64
# BABIP    10 non-null float64
# 타율       10 non-null float64
# 출루율      10 non-null float64
# 장타율      10 non-null float64
# OPS      10 non-null float64
# wOBA     10 non-null float64
# WAR      10 non-null float64
# dtypes: float64(13), int64(7)
# memory usage: 1.6+ KB

# %% [markdown]
# - 승률을 bar 그래프로 표현하기
# - 승률과 홈런 관계
# - 팀별 득점 점수
# - 승률과 실점
# - 나의 홈팀과 가장 유사한 성격의 팀을 찾아라

# %%
plt.rc('font', family='Malgun Gothic')
plt.barh(data.index, data['홈런']/data['홈런'].max(), label='홈런')
plt.barh(data.index, -data['승률']/data['승률'].max(), alpha=0.5, label='승률')
plt.legend()

# %%
plt.plot(data.index, data['득점'],  alpha=0.1)
plt.scatter(data.index, data['득점'])
plt.bar(data.index, data['득점'], alpha=0.3)
# Out:
# <BarContainer object of 10 artists>

# %%
# %승률, 기대승률, 타율, 출루율, 장타율
col = ['승률', '기대승률', '타율', '출루율', '장타율']
for c in col:
    plt.plot(data.index, data[c], label=c)
plt.plot(data.index, data['볼넷%']/data['볼넷%'].max(), label='볼넷')
plt.plot(data.index, data['삼진%']/data['삼진%'].max(), label='삼진')
plt.legend()

# %%
plt.title("홈런 비율")
p = plt.pie(data.홈런, labels=data.index,autopct='%.1f')

# %%
plt.title('경기당 득점 분포')
p = plt.hist(data.득점/data.경기, bins=10)

# %%
홈팀 = input('당신의 홈팀은 어디인가요 : ')
# Out:
# 당신의 홈팀은 어디인가요 : 롯데

# %%
홈팀
# Out:
# '롯데'

# %%
data_normal=data/data.max()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, SK to 롯데
# Data columns (total 20 columns):
# #        10 non-null float64
# 경기       10 non-null int64
# 승        10 non-null int64
# 무        10 non-null int64
# 패        10 non-null int64
# 승률       10 non-null float64
# 기대승률     10 non-null float64
# R/G      10 non-null float64
# 득점       10 non-null int64
# 홈런       10 non-null int64
# 도루       10 non-null int64
# 볼넷%      10 non-null float64
# 삼진%      10 non-null float64
# BABIP    10 non-null float64
# 타율       10 non-null float64
# 출루율      10 non-null float64
# 장타율      10 non-null float64
# OPS      10 non-null float64
# wOBA     10 non-null float64
# WAR      10 non-null float64
# dtypes: float64(13), int64(7)
# memory usage: 2.0+ KB

# %%
홈 = data_normal.loc[홈팀]
차이 = np.sum(np.square(data_normal - 홈), axis=1)
i = 차이.sort_values().index[:3]

# %%
data.loc[i].T.plot(figsize=(5,3))
